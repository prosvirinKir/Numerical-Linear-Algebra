# %% [markdown]
# <a href="https://colab.research.google.com/github/prosvirinKir/Numerical-Linear-Algebra/blob/main/NLA_HW1_ProsvirinKV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem Set 1 (96 points)

# %% [markdown]
# ## Important information
# 1. We provide signatures of the functions that you have to implement. Make sure you follow the signatures defined, otherwise your coding solutions will not be graded.
#
# 2. Please submit the single Jupyter Notebook file, where only Python and Markdown/$\LaTeX$ are used. Any hand-written solutions inserted by photos or in any other way **are prohibitive and will not be graded**. If you will have any questions about using Markdown, ask them!

# %% [markdown]
# # Problem 1 (Theoretical tasks)  (36 pts)
#
# _1._
# - (1 pts) What are the constants $C_1$ and $C_2$ such that $C_1 \|x\|_{1} \leq \|x\|_{\infty} \leq C_2 \| x\|_{1}$ for any vector $x$
#
# Consider $ || * ||_1 $ norm. $ || x ||_1 = \sum_{i=1}^m |x_i| \leq m \cdot max_i |x_i|
# \Rightarrow
# || x ||_1 \leq m \cdot|| x ||_{\infty} \Rightarrow C_1 = \frac{1}{m}$
#
# And for $ C_2 $ it is clear that maximum element $\leq$ sum of all elements $\Rightarrow C_2 = 1 $
#
# - (5 pts) Prove that $\| U A \|_F = \| A U \|_F = \| A \|_F$ for any unitary matrix $U$.
#
# $ || UA ||_F = \sqrt{tr((UA)^*UA)} = \sqrt{tr(A^*U^*UA)} = \sqrt{tr(A^*A)} = || A ||_F $
#
# On the other side: $ || A ||_F = \sqrt{tr(AA^*)} = \sqrt{tr(AUU^*A^*)} = \sqrt{tr(AU(AU)^*)} = || AU ||_F $
#
#
# - (5 pts) Prove that $\| U A \|_2 = \| A U \|_2 = \| A \|_2$ for any unitary matrix $U$.
#
# Prove that $ || Ux ||_2 = || x ||_2$: $ \ \   || Ux ||_2 = (Ux, Ux) = (x, U^*Ux) = (x, x) = || x ||_2 $.
#
# Taking this into account we can prove it, using spectral norm:
#
# $ || AU ||_2 = \sup_{x\ne 0}\dfrac{|| AUx ||_2}{|| x ||_2}
# = \sup_{x\ne 0}\dfrac{|| AUx ||_2}{|| Ux ||_2} = || A ||_2 $
#
# $ || UA ||_2 = \sup_{x\ne 0}\dfrac{|| (UA)x ||_2}{|| x ||_2} = \sup_{x\ne 0}\dfrac{|| U(Ax) ||_2}{|| x ||_2}
# = \sup_{x\ne 0}\dfrac{|| Ax ||_2}{|| x ||_2}= || A ||_2$

# %% [markdown]
#
# _2._
# - (5 pts) Using the results from the previous subproblem, prove that $\| A \|_F \le \sqrt{\mathrm{rank}(A)} \| A \|_2$. _Hint:_ SVD will help you.
#
# **Right hand side:**
#
# Taking into considiration that SVD $ A = V\Sigma U^* $ and $ || UA ||_2 = || A ||_2
# \Rightarrow || A ||_2 = || V\Sigma U^* ||_2 = || \Sigma ||_2 = \max(|\sigma_i|)$
#
# **Left hand side:**
#
# $ || A ||_F = \left(\sum_i\sum_j a_{ij}^2\right)^{1/2} $
# From the other hand: $ || A ||_F = \sqrt{tr(AA^*)}
# \Rightarrow  || A ||_F = || V\Sigma U^* ||_2 = \sqrt{tr(U\Sigma^* V^*V\Sigma U^*)} =
# \sqrt{tr(U\Sigma^*\Sigma U^*)} = \sqrt{tr(\Sigma^*\Sigma)} = || \Sigma ||_F $
#
# So, now we have $ || A ||_F = || \Sigma ||_F
# \Rightarrow || A ||_F = \sqrt{\sum_{i=1}^{rank(A)}\sigma_i^2}$
#
# **Bring all together**
# $ \sqrt{\sum_{i=1}^{rank(A)}\sigma_i^2} \leq \sqrt{rank(A)} \cdot \max(|\sigma_i|)
# \Rightarrow \sum_{i=1}^{rank(A)}\sigma_i^2 \leq rank(A) \cdot \max(\sigma_i^2)$
#
# - (5 pts) Show that for any $m, n$ and $k \le \min(m, n)$ there exists $A \in \mathbb{R}^{m \times n}: \mathrm{rank}(A) = k$, such that $\| A \|_F = \sqrt{\mathrm{rank}(A)} \| A \|_2$. In other words, show that the previous inequality is not strict.
#
# Let's consider $rank(A)=1$, then
# $ || A ||_F = \sum_{i=1}^{rank(A)}\sigma_i^2 = \sigma_1 = \max(\sigma_i^2) = || A ||_2$
#
# - (5 pts) Prove that if $A \in \mathbb{R}^{n \times n}$ - diagonalizable matrix, then $\det(\exp(A)) = \exp(\mathrm{trace}(A))$.
#
# _Hint:_ $\exp(S^{-1}AS) = \sum\limits_{k=0}^{\infty}\frac{(S^{-1}AS)^k}{k!} = S^{-1}\exp(A)S$, moreover $\exp(D) = \mathrm{diag}(\exp(d_1), \exp(d_2), ..., \exp(d_n))$ where $D = \mathrm{diag}(d_1, d_2, ..., d_n)$ - diagonal matrix with diagonal values $d_1, d_2, ..., d_n$
#
# It is given that A is diagonalizable, therefore $ \Sigma = M^{-1} A M $, where $M$ is the matrix
# that columns are eigenvectors of a matrix A and $\Sigma = \mathrm{diag}(\lambda_1, \ldots, \lambda_n)$
#
# Let's prove very quickly that a matrix $ \Sigma $ has *the same* evalues as a matrix A:
#
# $ \Sigma y = M^{-1} A M y = \lambda y \Rightarrow A(My) = \lambda(My) $.
# So, we can see that evalues didn't change, but evectors did change
# (matrix M just gives a different basis for evectors and didn't change evalues).
#
# It is also given, that $e^\Sigma = \mathrm{diag}(e^{\lambda_1}, \ldots, e^{\lambda_n})$.
# Thus $ \mathrm{det}(e^\Sigma) = e^{\lambda_1} \cdot \ldots \cdot e^{\lambda_n} =
# e^{{\lambda_1} + \ldots + {\lambda_n}} = e^{tr(\Sigma)}$
#
# Since $ \Sigma $ and A has *the same* evalues we get that $ \mathrm{tr}(\Sigma)=\mathrm{tr}(A) $.
# Uff, it's almost done.
#
# I think now its time for the *hint* $\exp(S^{-1}AS) = S^{-1}\exp(A)S$:
#
# $ \mathrm{det}(e^A) = \mathrm{det}(e^{M\Sigma M^{-1}}) = \mathrm{det}(Me^\Sigma M^{-1}) =
# \mathrm{det}(M)\mathrm{det}(e^{\Sigma})\mathrm{det}(M^{-1}) = \mathrm{det}(e^{\Sigma})
# = e^{tr(\Sigma)} = e^{tr(A)}$
#
#
# - (5 pts) Prove that $\| A B \|_2 \le \| A \|_2 \| B \|_F$.
#
# Firstly, prove that $ \| A B \|_2 \le \| A \|_2 \| B \|_2 $
#
# $ \| A B \|_2 =\sup_{x\ne 0}\dfrac{|| ABx ||_2}{|| x ||_2} =
# \sup_{Bx=\ne 0}\left(\dfrac{|| ABx ||_2}{|| Bx ||_2}\dfrac{|| Bx ||_2}{|| x ||_2}\right) \leq
# \sup_{x\ne 0}\dfrac{|| ABx ||_2}{|| Bx ||_2}\sup_{Bx\ne 0}\dfrac{|| Bx ||_2}{|| x ||_2} =
# || A ||_2 || B ||_2$
#
# Secondly, prove that $ || B ||_2 \leq || B ||_F $
#
# $ || B ||_2 = \max{|\sigma_i|} \leq \sqrt{\sum_i{\sigma_i^2}} = || B ||_F $
#
# Thus, $ \| A B \|_2 \le \| A \|_2 \| B \|_2 \leq \| A \|_2 \| B \|_F$

# %% [markdown]
# _3._
#
# - (2 pts) Let $U \in \mathbb{C}^{n \times k}, k < n$ be a matrix so that $U^*U = I_k$.
# Find a pseudoinverse of $UU^*$
#
# Let's use that fact that $ (UU^*)^*=UU^* $
#
# Prove that $(UU^*)^+ = UU^*$. by checking definition:
#
# 1. $A A^{+} A=A$
# $$
# U \underbrace{U^{*} \cdot U}_{I} \underbrace{U^{*} \cdot U }_{I}U^{*}=U U^{*}
# $$
# 2. $A^{+} A A^{+}=A^{+}$
# $$
# U \underbrace{U^{*} \cdot U}_{I} \underbrace{U^{*} \cdot U }_{I}U^{*}=U U^{*}
# $$
# 3. $\left(A A^{+}\right)^{*}=A A^{+}$
# $$
# (U \underbrace{U^{*} U }_{I}U^{*})^{*}=U \underbrace{U^{*} U }_{I}U^{*} \rightarrow U U^{*}=U U^{*}
# $$
# 4. $ (A^{+} A)^{*}=A^{+} A $
# $$
# (U \underbrace{U^{*} U }_{I}U^{*})^{*}=U \underbrace{U^{*} U }_{I}U^{*} \rightarrow U U^{*}=U U^{*}
# $$
# Thus, we prove that $ (UU^*)^+=UU^* $
# - (3 pts) Compute  pseudoinverse of the matrix analytically
#
# $$
# A = \begin{bmatrix}
# 2\\
# 3\\
# \vdots\\
# \sqrt{5n-1}
# \end{bmatrix}
# \begin{bmatrix}
# -1 & 1 & -1 & \ldots & (-1)^{n}
# \end{bmatrix}
# $$
#
# Let's norm
#
# $$
# \begin{array}{l}
# x=\left[\begin{array}{c}
# 2 \\
# 3 \\
# \vdots \\
# \sqrt{5 n-1}
# \end{array}\right], \quad y=\left[\begin{array}{c}
# -1 \\
# 1 \\
# \vdots \\
# (-1)^{n}
# \end{array}\right]\\
# (x, x)=2^{2}+3^{2}+\ldots+5 n-1=\frac{5 n-1+2^{2}}{2} \cdot n=\frac{5 n+3}{2} n\\
# (y, y)=1+1+\ldots+1=n\\
# U=\frac{2}{n(5 n+3)}\left[\begin{array}{c}
# 2 \\
# 3 \\
# \vdots \\
# \sqrt{5 n-1}
# \end{array}\right]\\
# V=\frac{1}{n}\left[\begin{array}{c}
# -1 \\
# 1 \\
# \vdots \\
# (-1)^{n}
# \end{array}\right]\\
# \sum=\frac{n^{2}(5 n+3)}{2}\\
# A=U \sum V^{*} \Rightarrow A^{+}=V \sum^{-1} U^{*}, \text{where } \Sigma^{-1}=\frac{2}{n^{2}(5 n+3)}
# \end{array}
# $$

# %% [markdown]
# # Problem 2 (Matrix calculus) (15 pts)
#
# _1._ (11 pts) Consider the following function
#
# $$ F(U, V) = \frac{1}{2}\|X - UDV\|_F^2, $$
#
# where $X \in \mathbb{R}^{n \times n}$, $U \in \mathbb{R}^{n \times k}$, $V \in \mathbb{R}^{k \times n}$, $k < n$ and $D = diag(d_1, \ldots, d_k)$ is given diagonal matrix.
#
# - (2 pts) Derive analytical expression for the gradient of the function $F$ with respect to $U$
#
# We will use several facts:
# 1. $ \dfrac{\partial}{\partial X}\mathrm{tr}(AX) = A^* $
# 2. $ \dfrac{\partial}{\partial X}\mathrm{tr}(X^*A) = A $
# 3. $ \mathrm{tr}(AB) = \mathrm{tr}(BA) $
#
# $ \dfrac{\partial}{\partial U}F(U, V)=
# \dfrac{\partial}{\partial U}\dfrac{1}{2}\mathrm{tr}
# \left(
#     (X-UDV)^*(X-UDV)
# \right)=
#     \dfrac{1}{2}\dfrac{\partial}{\partial U}\mathrm{tr}
#     \left(
#     (XX^* - X^*UDV - (UDV)^*X + (UDV)^*UDV
# \right)=
#     \dfrac{1}{2}\dfrac{\partial}{\partial U}
#     \left[
#     -\mathrm{tr}(UDVX^*) - \mathrm{tr}(XV^*D^*U^*) + \mathrm{tr}(UDVV^*D^*U^*)
# \right]=
# \dfrac{1}{2}
# \left[
#     -(DVX^*)^* - (XV^*D^*) + (DVV^*D^*U^*)^* + UDVV^*D^*
# \right]=
# UDVV^*D^* - XV^*D^* = (UDV - X)V^*D^*
# $
#
# - (2 pts) Derive analytical expression for the gradient of the function $F$ with respect to $V$
#
# $ \dfrac{\partial}{\partial V}F(U, V)=
# \dfrac{\partial}{\partial V}\dfrac{1}{2}\mathrm{tr}
# \left(
#     (X-UDV)^*(X-UDV)
# \right)=
#     \dfrac{1}{2}\dfrac{\partial}{\partial V}\mathrm{tr}
#     \left(
#     (XX^* - X^*UDV - (UDV)^*X + (UDV)^*UDV
# \right)=
#     \dfrac{1}{2}\dfrac{\partial}{\partial V}
#     \left[
#     -\mathrm{tr}(X^*UDV) - \mathrm{tr}(V^*D^*U^*X) + \mathrm{tr}(V^*D^*U^*UDV)
# \right]=
# \dfrac{1}{2}
# \left[
#     -(X^*UD)^* - (D^*U^*X) + (D^*U^*UDV) + (V^*D^*U^*UD)^*
# \right]=
# D^*U^*UDV - D^*U^*X = D^*U^*(UDV - X )
# $
#
# - (7 pts) Estimate computational complexity of computing these gradients (in big-O notation). Also, compare timing of analytical computations versus timing the automatic differentiation with JAX. Study some range of dimensions to extract asymptotic complexity and make a conclusion, what approach is faster. Plot the dependence of running time on the dimension (row and column separately) to proof your conclusion

# %% [markdown]
# The complexity of the product of matrices $(n, m)$ and $(m, k)$ is $O (n \cdot m \cdot k)$. The analytical formula for calculating gradients is a sequential product of matrices of the form $(n, n)$ or $(n, k)$ or $(k, n)$ or $(k, k)$.
#
# Here is an example:
# $$
# \underbrace{\underbrace{(\underbrace{U \times D }_{O\left(n \cdot k^{2}\right)}\times V}_{O\left(n^{2} \cdot k\right)}-X) \times \underbrace{V^{\top} \times D^{\top}}_{O\left(n \cdot k^{2}\right)}}_{O\left(n^{2} k\right)}
# $$
#
#
# Therefore, the complexity of the product could be only $O (n ^ 2 \cdot k)$ or $O (n \cdot k ^ 2)$. Then the final complexity will be of the form $O (n ^ 2 \cdot k) + O (n \cdot k ^ 2) = O (n \cdot k \cdot \max (n, k))$.
#
# Therefore, for constant K, we should see a quadratic dependence for N on the graph. And vice versa, for constant N we should see a quadratic dependence for K.

# %%
import numpy as np
import jax.numpy as jnp
from jax import grad, jit
import time
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def F_U(U, D, V, X):
    return 0.5 * jnp.sum((X - jnp.dot(U, jnp.dot(D, V))) ** 2)

def F_V(V, D, U, X):
    return 0.5 * jnp.sum((X - jnp.dot(U, jnp.dot(D, V))) ** 2)

def dFdU(U, D, V, X):
    return (U @ D @ V - X) @ V.T @ D.T

def dFdV(V, D, U, X):
    return D.T @ U.T @ (U @ D @ V - X)

# %% [markdown]
# **NOTE**: It is always very good to check everything is OK. So, let's check that our derivatives are the same in both approaches

# %%
n = 1000
k = 500

# %%
X, U, D, V = np.random.rand(n,n), np.random.rand(n,k), np.diag(np.random.rand(k)), np.random.rand(k,n)

# %%
JAX_dFdU = jit(grad(F_U))
JAX_dFdV = jit(grad(F_V))

# %%
print(f'Relative error: {np.mean((JAX_dFdU(U, D, V, X) - dFdU(U, D, V, X)) / dFdU(U, D, V, X))}')
print(f'Relative error: {np.mean((JAX_dFdV(V, D, U, X) - dFdV(V, D, U, X)) / dFdV(V, D, U, X))}')
# Out:
# Relative error: 1.9746193569147863e-09
# Relative error: 2.5507158607496194e-09

# %% [markdown]
# We can see that our derivatives are the same, hince we did it right.
#
# Now let's go to compare analytical and automatic approaches for computing gradients depending on number of N and K

# %% [markdown]
# ### Analytical and automatic computations for $\frac{\partial F(U, V)}{\partial U}$

# %%
n_timing = []
jax_n_timing = []
for n in range(1000, 10000, 500):
    k = 1000
    X, U, D, V = np.random.rand(n,n), np.random.rand(n,k), np.diag(np.random.rand(k)), np.random.rand(k,n)

    start = time.time()
    res = dFdU(U, D, V, X)
    stop = time.time()
    n_timing.append(stop - start)

    start = time.time()
    res = JAX_dFdU(U, D, V, X)
    stop = time.time()
    jax_n_timing.append(stop - start)

# %%
k_timing = []
jax_k_timing = []
for k in range(1000, 10000, 500):
    n = 1000
    X, U, D, V = np.random.rand(n,n), np.random.rand(n,k), np.diag(np.random.rand(k)), np.random.rand(k,n)

    start = time.time()
    res = dFdU(U, D, V, X)
    stop = time.time()
    k_timing.append(stop - start)

    start = time.time()
    res = JAX_dFdU(U, D, V, X)
    stop = time.time()
    jax_k_timing.append(stop - start)

# %% [markdown]
# **NOTE**: The first reason for such range for N and K is that it is a popular number of hidden neurones for neural networks.
#
# And the second reason is that we also want to estimate computational complexity of computing these gradients (in big-O notation), so we need quite large number of elements.

# %%
x = list(range(1000, 10000, 500))
plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.title('Timing for different N')
plt.plot(x, n_timing, color='blue', label='analytical')
plt.plot(x, jax_n_timing, color='red', label='jax')
plt.ylabel(f"time", fontsize=12)
plt.xlabel(f"amount of N", fontsize=12)

plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.title('Timing for different K')
plt.plot(x, k_timing, color='blue', label='analytical')
plt.plot(x, jax_k_timing, color='red', label='jax')
plt.ylabel(f"time", fontsize=12)
plt.xlabel(f"amount of K", fontsize=12)

plt.legend()
plt.grid()

plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.title('Timing for different N')
plt.plot(np.log(x), np.log(n_timing), color='blue', label='analytical')
plt.plot(np.log(x), np.log(jax_n_timing), color='red', label='jax')
plt.ylabel(f"ln(time)", fontsize=12)
plt.xlabel(f"ln(amount of N)", fontsize=12)

plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.title('Timing for different K')
plt.plot(np.log(x), np.log(k_timing), color='blue', label='analytical')
plt.plot(np.log(x), np.log(jax_k_timing), color='red', label='jax')
plt.ylabel(f"ln(time)", fontsize=12)
plt.xlabel(f"ln(amount of K)", fontsize=12)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# **Note**: It is interesting fact from these graphs that JAX optimized better for computing 1000, 2000 ... rather that 1500, 2500 ...

# %% [markdown]
# In the theory linear regression model basically finds the best value for the intercept and slope, which results in a line that best fits the data.
#
# So, let's calculated value of the intercept and slop:

# %%
from sklearn.linear_model import LinearRegression

# %%
X = np.log(x).reshape(-1, 1)
y = np.log(n_timing)
lm = LinearRegression()
lm.fit(X, y)
print(f'Slope coef depending on N = {lm.coef_[0]:.3f}')

X = np.log(x).reshape(-1, 1)
y = np.log(jax_n_timing)
lm = LinearRegression()
lm.fit(X, y)
print(f'Slope coef for JAX depending on N= {lm.coef_[0]:.3f}')
# Out:
# Slope coef depending on N = 1.715
# Slope coef for JAX depending on N= 1.111

# %%
X = np.log(x).reshape(-1, 1)
y = np.log(k_timing)
lm = LinearRegression()
lm.fit(X, y)
print(f'Slope coef depending on K = {lm.coef_[0]:.3f}')

X = np.log(x).reshape(-1, 1)
y = np.log(jax_k_timing)
lm = LinearRegression()
lm.fit(X, y)
print(f'Slope coef for JAX depending on K= {lm.coef_[0]:.3f}')
# Out:
# Slope coef depending on K = 1.727
# Slope coef for JAX depending on K= 1.129

# %% [markdown]
# **NOTE**: We see that the degree is a little bit lower than we predicted. It is a little lower than two. This may be due to the fact that the numpy has built-in accelerators for calculating the product of matrices (and it has of course).

# %% [markdown]
# Nevertheless, now we can see from these coefficients that JAX is faster more by 50% than analytical computation and it is slightly above than liniar dependence. It's a greate observation!

# %% [markdown]
# Now we have to do it one more time for the second derivative:

# %% [markdown]
# ### Automatic differentiation with JAX for $\frac{\partial F(U, V)}{\partial V}$

# %%
n_timing = []
jax_n_timing = []
for n in range(1000, 10000, 500):
    k = 1000
    X, U, D, V = np.random.rand(n,n), np.random.rand(n,k), np.diag(np.random.rand(k)), np.random.rand(k,n)

    start = time.time()
    res = dFdV(V, D, U, X) # change here
    stop = time.time()
    n_timing.append(stop - start)

    start = time.time()
    res = JAX_dFdV(V, D, U, X) # change here
    stop = time.time()
    jax_n_timing.append(stop - start)

# %%
k_timing = []
jax_k_timing = []
for k in range(1000, 10000, 500):
    n = 1000
    X, U, D, V = np.random.rand(n,n), np.random.rand(n,k), np.diag(np.random.rand(k)), np.random.rand(k,n)

    start = time.time()
    res = dFdV(V, D, U, X) # change here
    stop = time.time()
    k_timing.append(stop - start)

    start = time.time()
    res = JAX_dFdV(V, D, U, X) # change here
    stop = time.time()
    jax_k_timing.append(stop - start)

# %%
x = list(range(1000, 10000, 500))
plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.title('Timing for different N')
plt.plot(x, n_timing, color='blue', label='analytical')
plt.plot(x, jax_n_timing, color='red', label='jax')
plt.ylabel(f"time", fontsize=12)
plt.xlabel(f"amount of N", fontsize=12)

plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.title('Timing for different K')
plt.plot(x, k_timing, color='blue', label='analytical')
plt.plot(x, jax_k_timing, color='red', label='jax')
plt.ylabel(f"time", fontsize=12)
plt.xlabel(f"amount of K", fontsize=12)

plt.legend()
plt.grid()

plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.title('Timing for different N')
plt.plot(np.log(x), np.log(n_timing), color='blue', label='analytical')
plt.plot(np.log(x), np.log(jax_n_timing), color='red', label='jax')
plt.ylabel(f"ln(time)", fontsize=12)
plt.xlabel(f"ln(amount of N)", fontsize=12)

plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.title('Timing for different K')
plt.plot(np.log(x), np.log(k_timing), color='blue', label='analytical')
plt.plot(np.log(x), np.log(jax_k_timing), color='red', label='jax')
plt.ylabel(f"ln(time)", fontsize=12)
plt.xlabel(f"ln(amount of K)", fontsize=12)
plt.legend()
plt.grid()
plt.show()

# %%
X = np.log(x).reshape(-1, 1)
y = np.log(n_timing)
lm = LinearRegression()
lm.fit(X, y)
print(f'Slope coef depending on N = {lm.coef_[0]:.3f}')

X = np.log(x).reshape(-1, 1)
y = np.log(jax_n_timing)
lm = LinearRegression()
lm.fit(X, y)
print(f'Slope coef for JAX depending on N= {lm.coef_[0]:.3f}')
# Out:
# Slope coef depending on N = 1.735
# Slope coef for JAX depending on N= 1.117

# %%
X = np.log(x).reshape(-1, 1)
y = np.log(k_timing)
lm = LinearRegression()
lm.fit(X, y)
print(f'Slope coef depending on K = {lm.coef_[0]:.3f}')

X = np.log(x).reshape(-1, 1)
y = np.log(jax_k_timing)
lm = LinearRegression()
lm.fit(X, y)
print(f'Slope coef for JAX depending on K= {lm.coef_[0]:.3f}')
# Out:
# Slope coef depending on K = 1.722
# Slope coef for JAX depending on K= 1.191

# %% [markdown]
# Almost the same coefficients for the second derivate.
#
# So, we can make a conclusion that for both N and K the JAX is faster than analytical approach more by 50%.

# %% [markdown]
# _2._ (4 pts) Derive analytical expression for the gradient and hessian of the function $f$:
#
# $$ R(x) = \frac{(Ax, x)}{(x, x)}, $$
#
# where $A$ is a symmetric real matrix. Why the gradient of this function is important in NLA you will know in the lectures later.

# %% [markdown]
# $$
# \nabla R(x) = \frac{\partial R(x)}{\partial x}=\frac{\frac{\partial}{\partial x}(A x, x) \cdot(x, x)-\frac{\partial}{\partial x}(x, x) \cdot(A x, x)}{(x, x)^{2}}
# =\frac{2 A x(x, x)-2 x(A x, x)}{(x, x)^{2}}=\frac{2 A x}{(x, x)}-\frac{(A x, x)}{(x, x)^{2}} \cdot 2 x
# =\frac{2 A x}{(x, x)}-\frac{2 x}{(x, x)} \cdot R(x)=\frac{2}{(x, x)}(A x-R(x) \cdot x)
# $$

# %% [markdown]
# $$
# \Delta R(x) = \frac{\partial^{2}}{\partial x^{2}} R(x)=\frac{\partial}{\partial x}\left(\frac{\partial R(x)}{\partial x}\right)=\frac{\partial}{\partial x}\left[\frac{2(A x-R(x) \cdot x)}{(x, x)}\right]
# =(A x-R(x) \cdot x) \frac{\partial}{\partial x}\left(\frac{2}{(x, x)}\right)+\frac{2}{(x, x)} \frac{\partial}{\partial x}(A x-R(x) \cdot x)=\\
# =(A x-R(x) \cdot x)\left(\frac{-2 x}{(x, x)^{2}}\right)+\frac{2}{(x, x)}\left(A-x \cdot \nabla R^{\top}(x)-R(x) \cdot I\right)=\\
# =-\frac{2\nabla R(x)}{(x, x)} x^{\top}+\frac{2}{(x, x)}\left(A-x \cdot \nabla R^{\top}(x)-R(x) \cdot I\right)
# =\frac{2}{(x, x)}\left(A-x \cdot \nabla R^{\top}(x)-R(x) \cdot I- \nabla R(x) \cdot x^{\top}\right)
# $$

# %% [markdown]
# # Problem 3. Compression of the fully-connected layers in neural network with simple architecture (30 pts)
#
# In this problem we consider the neural network that performs classification of the dataset of images.
# Any neural network can be considered as composition of simple linear and non-linear functions.
# For example, a neural network with 3 layers can be represented as
#
# $$f_3(f_2(f_1(x, w_1), w_2), w_3),$$
#
# where $x$ is input data (in our case it will be images) and $w_i, \; i =1,\dots,3$ are parameters that are going to be trained.
#
# We will study the compression potential of neural network with simple architecture: alternating some numbers of linear and non-linear functions.
#
# The main task in this problem is to study how the compression of fully-connected layers affects the test accuracy.
# Any fully-connected layer is represented as linear function $AX + B$, where $X$ is input matrix and $A, B$ are trainable matrices. Matrices $A$ in every layer are going to be compressed.
# The main result that you should get is the plot of dependence of test accuracy on the total number of parameters in the neural network.

# %% [markdown]
# #### Zero step: install PyTorch
#
# - Follow the steps in [official instructions](https://pytorch.org/get-started/locally/)

# %% [markdown]
# #### First step: download CIFAR10 dataset

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets, transforms
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

batch_size = 100

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_loader = torch.utils.data.DataLoader(datasets.CIFAR10('./', train=True, download=True, transform=transform), 
                                        batch_size=batch_size, shuffle=True)

test_loader = torch.utils.data.DataLoader(datasets.CIFAR10('./', train=False, transform=transform), 
                                          batch_size=batch_size, shuffle=True)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# ...
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./cifar-10-python.tar.gz to ./

# %% [markdown]
# #### Check what images are we going to classify

# %%
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.figure(figsize=(20, 10))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(train_loader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(8)))
# Out:
#   dog  bird truck truck  frog truck truck  ship

# %% [markdown]
# ### Second step: neural network architecture
#
# For simplicity and demonstration purposes of the neural network compression idea consider the architecture consisting of the only fully-connected layers and non-linear ReLU functions between them.
# To demonstrate compression effect, consider the dimension of the inner layers equals to 1000.
#
# Below you see implementation of such neural network in PyTorch.
# More details about neural networks you will study in the *Deep learning* course in one of the upcoming term

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_features, middle_features, activation=nn.ReLU()):
        super().__init__()
        self.layer1 = nn.Linear(in_features, middle_features)
        self.layer2 = nn.Linear(middle_features, in_features)
        self.activation = activation
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.activation(out)
        out = self.layer2(out)
        out = out + x
        out = self.activation(out)
        return out

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(3 * 32 * 32, 1000)
        self.res1 = ResidualBlock(1000,1000)
        self.res2 = ResidualBlock(1000,1000)
        self.fc2 = nn.Linear(1000, 10)
        self.ReLU = nn.ReLU()

    def forward(self, x):
        x = self.fc1(x.view(-1, 3 * 32*32))
        x = self.ReLU(x)
        x = self.res1(x)
        x = self.res2(x)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %% [markdown]
# #### Implement functions for training and testing after every sweep over all dataset entries

# %%
def train(model, train_loader, optimizer, epoch):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.train()
    model.to(device)
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

# %%
def test(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    device = "cuda" if torch.cuda.is_available() else "cpu"
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return 100. * correct / len(test_loader.dataset)

# %% [markdown]
# ### Set parameters for training and print intermediate loss values

# %%
log_interval = 50
epochs = 7

# %% [markdown]
# ### Third step: run training with the [Adam](https://arxiv.org/pdf/1412.6980.pdf%20%22%20entire%20document) optimization method
#
# If your laptop is not very fast, you will wait some time till training is finished.

# %%
model = Net()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

for epoch in range(1, epochs + 1):
    train(model,  train_loader, optimizer, epoch)
    test(model, test_loader)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.322896
# Train Epoch: 1 [5000/50000 (10%)]	Loss: 1.608533
# Train Epoch: 1 [10000/50000 (20%)]	Loss: 1.614600
# Train Epoch: 1 [15000/50000 (30%)]	Loss: 1.442590
# Train Epoch: 1 [20000/50000 (40%)]	Loss: 1.716647
# Train Epoch: 1 [25000/50000 (50%)]	Loss: 1.449161
# Train Epoch: 1 [30000/50000 (60%)]	Loss: 1.566957
# Train Epoch: 1 [35000/50000 (70%)]	Loss: 1.565963
# Train Epoch: 1 [40000/50000 (80%)]	Loss: 1.570816
# Train Epoch: 1 [45000/50000 (90%)]	Loss: 1.580898
#
# Test set: Average loss: 1.4855, Accuracy: 4788/10000 (48%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.178251
# Train Epoch: 2 [5000/50000 (10%)]	Loss: 1.427301
# Train Epoch: 2 [10000/50000 (20%)]	Loss: 1.376502
# Train Epoch: 2 [15000/50000 (30%)]	Loss: 1.259747
# Train Epoch: 2 [20000/50000 (40%)]	Loss: 1.244462
# Train Epoch: 2 [25000/50000 (50%)]	Loss: 1.410873
# Train Epoch: 2 [30000/50000 (60%)]	Loss: 1.331681
# Train Epoch: 2 [35000/50000 (70%)]	Loss: 1.272758
# ...

# %% [markdown]
# Now we have somehow trained neural network and we are ready to perform compression of the weigths in the fully-connected layers.

# %% [markdown]
# - (3 pts) Compute SVD of the matrix $1000 \times 1000$, which corresponds to a weight matrix $A$ in each layer of residual blocks. To find more information about accessing this matrix please refer to [PyTorch manual](https://pytorch.org/docs/stable/index.html).
# Plot decaying of the singular values like it was shown in the lecture. What conclusion can you make?
# - (17 pts) Create a new model, which is an analogue to the class ```Net```, but with some significant distinctions.
# It takes as input parameters the instance of the class ```Net``` and compression rank $r > 0$.
# After that, this model has to compress all matrices $A$ in fully-connected layers with SVD using first $r$ singular vectors and singular values.
# Pay attention to efficient storing of compress representation of the layers.
# Also ```forward``` method of your new residual block has to be implemented in a way to use compressed representation of the fully-connected layers (inside it) in the most efficient way. In all other aspects it has to reproduce ```forward``` method in the original non-compressed model (number of layers, activations, loss function etc).
# - (5 pts) Plot dependence of test accuracy on the number of parameters in the compressed model. This number of parameters obviously depends on the compression rank $r$.
# Also plot dependence of time to compute inference on the compression rank $r$.
# Explain obtained results.
# To measure time, use [%timeit](https://docs.python.org/3.6/library/timeit.html) with necessary parameters (examples of using this command see in lectures)
#
# - (5 pts) After such transformations, your model depends on the factors obtained from SVD. Therefore, these factors are also can be trained with the same gradient method during some number of epochs. This procedure is called **fine-tuning**. We ask you make this fine-tuning of your compressed model during from 1 to 5 epochs and compare the result test accuracy with the test accuracy that you get after compression. Explain the observed results.
#
#     **Hint 1**. Please, check that during fine-tuning, factors are updated. If they are not updated according to some reason, please check that their parameter ```requires_grad``` is setted to ```True```.
#
#     **Hint 2**. You can use class ```torch.nn.Parameter``` to convert factors to parameters of the network

# %%
# Your solution is here
model
# Out:
# Net(
#   (fc1): Linear(in_features=3072, out_features=1000, bias=True)
#   (res1): ResidualBlock(
#     (layer1): Linear(in_features=1000, out_features=1000, bias=True)
#     (layer2): Linear(in_features=1000, out_features=1000, bias=True)
#     (activation): ReLU()
#   )
#   (res2): ResidualBlock(
#     (layer1): Linear(in_features=1000, out_features=1000, bias=True)
#     (layer2): Linear(in_features=1000, out_features=1000, bias=True)
#     (activation): ReLU()
#   )
#   (fc2): Linear(in_features=1000, out_features=10, bias=True)
#   (ReLU): ReLU()
# )

# %%
A_res1 = []

for p in model.res1.parameters():
  if len(p.shape) == 2:
    A_res1.append(p.detach().cpu())

A_res2 = []
for p in model.res2.parameters():
  if len(p.shape) == 2:
    A_res2.append(p.detach().cpu())

# %%
plt.rc("text", usetex=False)

def do_svd(A, drow_plot=True, title=''):
  u, s, v = jnp.linalg.svd(a)
  if drow_plot:
    plt.semilogy(s[:]/s[0], 'x')
    plt.ylabel(f"$\sigma_i / \sigma_0$", fontsize=12)
    plt.xlabel(f"Singular value index, $i$", fontsize=12)
    plt.title(title)
    plt.grid(True)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)
    plt.show()

  return u, s, v

# %%
for a in A_res1:
  do_svd(a, title='res1')

# %%
for a in A_res2:
  do_svd(a, title='res2')

# %% [markdown]
# From these graphs, we can see that most of the singular numbers are small relative to the first singular number. Therefore, the effective rank of the matrix is less than 1000. So, compression can potentially be effective, since most important information won't be lost.

# %% [markdown]
# (17 pts) Create a new model, which is an analogue to the class Net, but with some significant distinctions. It takes as input parameters the instance of the class Net and compression rank 𝑟>0 . After that, this model has to compress all matrices 𝐴 in fully-connected layers with SVD using first 𝑟 singular vectors and singular values. Pay attention to efficient storing of compress representation of the layers. Also forward method of your new residual block has to be implemented in a way to use compressed representation of the fully-connected layers (inside it) in the most efficient way. In all other aspects it has to reproduce forward method in the original non-compressed model (number of layers, activations, loss function etc).

# %%
class NewResidualBlock(nn.Module):
    def __init__(self, net_res, r):
        super().__init__()
        U, S, Vh = torch.linalg.svd(net_res.layer1.weight) 
        self.u1 = torch.nn.Parameter(U[:, :r])
        self.s1 = torch.nn.Parameter(S[:r]) 
        self.vh1 = torch.nn.Parameter(Vh[:r, :])
        self.b1 = net_res.layer1.bias

        U, S, Vh = torch.linalg.svd(net_res.layer2.weight)
        self.u2 = torch.nn.Parameter(U[:, :r])
        self.s2 = torch.nn.Parameter(S[:r])
        self.vh2 = torch.nn.Parameter(Vh[:r, :])
        self.b2 = net_res.layer2.bias

        self.activation = net_res.activation
        
    def forward(self, x):
        out = x @ (self.u1 @ torch.diag(self.s1) @ self.vh1).T  + self.b1
        out = self.activation(out)
        out = out @ (self.u2 @ torch.diag(self.s2) @ self.vh2).T + self.b2
        out = out + x
        out = self.activation(out)
        return out

class NewNet(nn.Module):
    def __init__(self, net, r):
        super(NewNet, self).__init__()
        self.fc1 = net.fc1
        self.res1 = NewResidualBlock(net.res1, r)
        self.res2 = NewResidualBlock(net.res2, r)
        self.fc2 = net.fc2
        self.ReLU = nn.ReLU()

    def forward(self, x):
        x = self.fc1(x.view(-1, 3 * 32*32))
        x = self.ReLU(x)
        x = self.res1(x)
        x = self.res2(x)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %% [markdown]
# In the code above I applyed SVD only for residual blocks.
#
# Since, SVD helps to store a matrix in a more efficient way, we use SVD to reduce the amount of memory occupied by hidden layers from $O(n^2)$ to $O(nr)$, where r is the compression rank, n - hidden size.
#
# Сoncerning the input and output linear layers, they depend on $n$ linearly. Thus, with SVD you won't get a significant decrease in the memory usage, however, we can lose important information.

# %% [markdown]
# (5 pts) Plot dependence of test accuracy on the number of parameters in the compressed model. This number of parameters obviously depends on the compression rank 𝑟 . Also plot dependence of time to compute inference on the compression rank 𝑟 . Explain obtained results. To measure time, use %timeit with necessary parameters (examples of using this command see in lectures)

# %%
import time
r_arr = list(range(1, 10, 2)) + [50]+ list(range(100, 1000, 100))
acc_by_r = []
time_by_r = []

for r in r_arr:
  new_model = NewNet(model, r=r)
  start = time.time()
  acc = test(new_model, test_loader)
  time_by_r.append((time.time() - start))
  acc_by_r.append(acc)

# %%
start = time.time()
original_acc = test(model, test_loader)
original_time = time.time() - start
# Out:
# Test set: Average loss: 1.8715, Accuracy: 5246/10000 (52%)

# %%
plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.title('accuracy by r')
plt.plot(r_arr, acc_by_r, color='blue', label='compressed')
plt.plot(r_arr, [original_acc] * len(r_arr), color='red', label='original')
plt.ylabel(f"accuracy", fontsize=12)
plt.xlabel(f"r", fontsize=12)

plt.legend(); plt.grid()

plt.subplot(1, 2, 2)
plt.title('time by r')
plt.plot(r_arr, time_by_r, color='blue', label='compressed')
plt.plot(r_arr, [original_time] * len(r_arr), color='red', label='original')
plt.ylabel(f"time", fontsize=12)
plt.xlabel(f"r", fontsize=12)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# We can see from the graph that already starting from rank $r=50$ we get the accuracy approx to the original model.
#
# However, because of that fact that now we need to compute 3 matrix muliplication instead of one in forward method, inference time increases with an increase in $r$.

# %% [markdown]
# (5 pts) After such transformations, your model depends on the factors obtained from SVD. Therefore, these factors are also can be trained with the same gradient method during some number of epochs. This procedure is called fine-tuning. We ask you make this fine-tuning of your compressed model during from 1 to 5 epochs and compare the result test accuracy with the test accuracy that you get after compression. Explain the observed results.

# %%
new_model = NewNet(model, r=10)
acc_arr = []
acc_arr.append(test(new_model, test_loader))
# Out:
# Test set: Average loss: 1.7622, Accuracy: 5165/10000 (52%)

# %% [markdown]
# The reason for such $r$ is that it is small enough to compress the model in terms of memory usage. And we can check whether our compressed model can reach the same accuracy as an original model or not.

# %%
optimizer = optim.Adam(new_model.parameters(), lr=1e-3)

for epoch in range(1, 6):
    train(new_model,  train_loader, optimizer, epoch)
    acc_arr.append(test(new_model, test_loader))
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 0.589531
# Train Epoch: 1 [5000/50000 (10%)]	Loss: 0.507938
# Train Epoch: 1 [10000/50000 (20%)]	Loss: 0.571694
# Train Epoch: 1 [15000/50000 (30%)]	Loss: 0.675158
# Train Epoch: 1 [20000/50000 (40%)]	Loss: 0.559950
# Train Epoch: 1 [25000/50000 (50%)]	Loss: 0.677289
# Train Epoch: 1 [30000/50000 (60%)]	Loss: 0.733555
# Train Epoch: 1 [35000/50000 (70%)]	Loss: 0.792479
# Train Epoch: 1 [40000/50000 (80%)]	Loss: 0.592083
# Train Epoch: 1 [45000/50000 (90%)]	Loss: 0.609391
#
# Test set: Average loss: 1.7017, Accuracy: 5205/10000 (52%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 0.384961
# Train Epoch: 2 [5000/50000 (10%)]	Loss: 0.487276
# Train Epoch: 2 [10000/50000 (20%)]	Loss: 0.349361
# Train Epoch: 2 [15000/50000 (30%)]	Loss: 0.457271
# Train Epoch: 2 [20000/50000 (40%)]	Loss: 0.534018
# Train Epoch: 2 [25000/50000 (50%)]	Loss: 0.567210
# Train Epoch: 2 [30000/50000 (60%)]	Loss: 0.674134
# Train Epoch: 2 [35000/50000 (70%)]	Loss: 0.523838
# ...

# %%
plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.title('fine-tuning model with svd')
plt.plot(list(range(0, 6)), acc_arr, color='blue', label='compressed, r = 10')
plt.plot(list(range(0, 6)), [original_acc] * 6, color='red', label='original')
plt.ylabel(f"accuracy", fontsize=12)
plt.xlabel(f"epoch", fontsize=12)
plt.legend()
plt.grid()

# %% [markdown]
# We were able to slightly beat the original model accuracy with fine-tuning. Thus, we can make a conclusion that *truncated* SVD matrices is able to reproduce the same linear mapping as an original matrix A with shape=(1000, 1000). The reason for that is that amount of learnable parameters in this decomposition is still enough to approx data with the same accuracy as an original model.

# %% [markdown]
# ## Problem 4. «Reducio!» (15 pts)

# %% [markdown]
# Hermione Granger is well versed in all magical disciplines. In particular, she is a great expert in Numerical Linear Algebra and JAX.
#
# She has invited Harry Potter to play the game.
#
# Hermione chooses a number $r \in [1, 95]$ and two matrices $W_1 \in \mathbb{R}^{r \times 100}$ and $W_2 \in \mathbb{R}^{100 \times r}$.
# Harry can tell her any 100-dimensional vector $x$, and Hermione gives Harry the result of
#
# $$ ||\sin(W_2 \cos(W_1 x))||^2_2,$$
#
# where trigonometric functions are applied element-wise. The result is the squared norm of a 100-dimensional vector.
#
# Not to lose, Harry should guess what number $r$ Hermione has chosen.
# Harry knows the python language, but he is an absolute layman in algebra. Please, help him to get at least 95% correct answers!
#
# <i> Hint 1: SVD might help you, but use it wisely! </i>
#
# <i> Hint 2: Suppose that a special magic allows you to compute gradients through automatic differentiation in JAX. You can also estimate gradients via finite differences, if you want it.</i>
#
# <i> Hint 3: You can estimate the matrix rank using simple heuristics.
#
# You should write code into the `harry_answers` function. Good luck!

# %%
import jax.numpy as jnp
import jax
import numpy as np
import random
from jax import grad, jit

class Game:
    def __init__(self, key):
        # key is a jax.random.PRNGKey
        self.key = key
        return
    def hermione_chooses_r_and_W(self):
        self.r = random.randint(1, 95)
        self.key, subkey = jax.random.split(self.key)
        self.W1 = jax.random.uniform(subkey, (self.r, 100), maxval=100., minval=0., dtype=jnp.float32)
        self.key, subkey = jax.random.split(self.key)
        self.W2 = jax.random.uniform(subkey, (100, self.r), maxval=100., minval=0., dtype=jnp.float32)
    def hermione_computes_function(self, x):
        return jnp.sum(jnp.square(jnp.sin(self.W2 @ jnp.cos(self.W1 @ x))))
    def harry_answers(self):
        # <your code here>
        # you shouldn't use self.r, self.W1, or self.W2
        # you can call `hermione_computes_function` multiple times

        m = 95 # choose 95 because of r<=95, so, there is no reason to choose bigger m
        dfoo = jax.jacfwd(self.hermione_computes_function, argnums=0)
        x = jax.random.normal(self.key, (100, m))
        dF = dfoo(x)
        sigmas = np.linalg.svd(dF, compute_uv=False)  # take singular values
        r = (sigmas > sigmas[0] * 1e-5).sum() # choose sigmas which not much less than the first one
        return r
    
    def play(self, n_rounds, verbose=True):
        # n_rounds: a number of rounds of the game
        # verbose: print or not the result of each round
        n_right_answers = 0
        for _ in range(n_rounds):
            self.hermione_chooses_r_and_W()
            r = self.harry_answers()
            if abs(r - self.r) == 0:
                if verbose:
                    print("Good job! The true answer is {}, Harry's answer is {}!".format(self.r, r))
                n_right_answers += 1
            else:
                if verbose:
                    print("Harry's answers is {}, but the true answer is {} :(".format(r, self.r))
        if float(n_right_answers) / n_rounds > 0.95:
            print('Well done: {}/{} right answers!'.format(n_right_answers, n_rounds))
        else:
            print('Only {}/{} right answers :( Work a little more and you will succeed!'.format(
                n_right_answers, n_rounds))

# %%
key = jax.random.PRNGKey(713)
game = Game(key)
game.play(n_rounds=100, verbose=False)
# Out:
# Well done: 99/100 right answers!
